# %%
from yfin import get_yfin_data

# %%
nvda = get_yfin_data(ticker="NVDA", start_date="2024-12-01", end_date="2025-04-20", interval="1d")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nvda.Close.plot(title="NVIDIA Close Price", ylabel="Price (USD)", xlabel="Date", legend=True, grid=True)
# Out:
# <Axes: title={'center': 'NVIDIA Close Price'}, xlabel='Date', ylabel='Price (USD)'>
